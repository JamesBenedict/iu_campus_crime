# %%
# %load_ext autoreload
# %autoreload 2
import os
import glob
import random
import re
from datetime import *

#from iucrime.records import Record

# %%
path = '../../data/scrapped/text/2016'
files = glob.glob(os.path.join(path, '*'))
# fname = random.choice(files)

print(open(path+'/1-4-16.txt').read())
# Out:
# Indiana University, Bloomington
#
# Police Department
# Daily Crime Log
# from 01/04/2016 00:00 to 01/04/2016 23:59
# date reported: 01/04/16 - MON at 12:45
# general location:
#
# report #:
#
# 160007
#
# HPER -SCHOOL OF PUBLIC HEALTH - On Campus
#
# date occurred from: 01/03/16 - SUN at 12:00
# date occurred to:
#
# 01/04/16 - MON at 12:30
#
# incident/offenses:
#
# OTHER ASSAULTS - SIMPLE, NOT AGGRAVATED // OTHER DISTURBANCES
#
# disposition: REFERRED
# modified date: 01/05/16 - TUE at 08:38
# date reported: 01/04/16 - MON at 13:19
# general location:
#
# report #:
#
# 160008
#
# MUSIC PRACTICE BLDG - On Campus
#
# date occurred from: 12/23/15 - WED at 13:19
# date occurred to:
#
# 01/03/16 - SUN at 14:00
#
# incident/offenses:
#
# VANDALISM, MISCHIEF
#
# disposition: OPEN CASE
# modified date: 01/04/16 - MON at 14:21
# date reported: 01/04/16 - MON at 13:39
# general location:
#
# report #:
#
# 160009
#
# RADIO AND TV - On Campus
#
# date occurred from: 12/22/15 - TUE at 12:00
# date occurred to:
#
# 12/28/15 - MON at 17:00
#
# incident/offenses:
#
# VANDALISM, MISCHIEF
#
# disposition: OPEN CASE
# modified date: 01/05/16 - TUE at 14:48
# date reported: 01/04/16 - MON at 14:33
# general location:
#
# report #:
#
# 160010
#
# FOREST QUAD - On Campus - in any student residential facility
#
# date occurred from: 12/18/15 - FRI at 09:00
# date occurred to:
#
# 01/04/16 - MON at 14:35
#
# incident/offenses:
#
# THEFT-BICYCLES
#
# disposition: OPEN CASE
# modified date: 01/04/16 - MON at 16:07
# date reported: 01/04/16 - MON at 17:27
# general location:
#
# report #:
#
# 160013
#
# IU CREDIT UNION - Non-campus building or property
#
# date occurred from: 01/04/16 - MON at 17:00
# date occurred to:
#
# 01/04/16 - MON at 17:05
#
# incident/offenses:
#
# ALL TYPES OF FRAUD
#
# disposition: OPEN CASE
# modified date: 01/05/16 - TUE at 21:38
#
# Indiana University, Bloomington
#
# Police Department
# Daily Crime Log
# from 01/04/2016 00:00 to 01/04/2016 23:59
# date reported: 01/04/16 - MON at 22:13
# general location:
#
# report #:
#
# 160011
#
# BANTA APTS. - On Campus - in any student residential facility
#
# date occurred from: 01/04/16 - MON at 22:05
# date occurred to:
#
# 01/04/16 - MON at 22:13
#
# incident/offenses:
#
# POSSESSION OF DRUG PARAPHERNALIA
#
# disposition: CLOSED CASE- ARREST
# modified date: 01/05/16 - TUE at 09:36

# %%
""" module for parsing text files that are converted from pdfs """
import re
from datetime import datetime

class Record():
    """ class for keeping the daily IU police log """

    INFO_PATTERN = re.compile('^(location|incident|disposition|event #|report #)\s*:\s*(.+)', re.IGNORECASE)
    TIME_PATTERN = re.compile('^date and time occurred.*from.*to', re.IGNORECASE)

    def __init__(self, content):
        self.info = {} 
        self.parse(content)

    def parse(self, content):
        line_itr = iter(content.splitlines())
        for line in line_itr:
            m = re.search(Record.INFO_PATTERN, line)
            if m:
                key = m.group(1).lower().replace('#', 'number')
                val = m.group(2).lower()
                self.info[key] = val
                continue

            if re.match(Record.TIME_PATTERN, line):
                line = next(line_itr)
                t_from, t_to = self.parse_from_to_time(line)
                self.info['from datetime'] = t_from
                self.info['to datetime'] = t_to

    def parse_from_to_time(self, timestr):
        fromdate, fromtime, todate, totime = timestr.split('-')
        fromtime = fromtime.split('at')[1].strip()
        totime = totime.split('at')[1].strip()
        t_from = datetime.strptime(' '.join([fromdate.strip(), fromtime]), '%m/%d/%y %H:%M')
        t_to = datetime.strptime(' '.join([todate.strip(), totime]), '%m/%d/%y %H:%M')
        return (t_from, t_to)
    
r = Record(open(fname).read())
# assert(r.info['location'] == 'indiana memorial union')
# assert(r.info['incident'] == 'all other offenses - trespass & malicious trespass')
pprint(r.info)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-bbec6d487581> in <module>()
#      37         return (t_from, t_to)
#      38
# ---> 39 r = Record(open(fname).read())
#      40 # assert(r.info['location'] == 'indiana memorial union')
#      41 # assert(r.info['incident'] == 'all other offenses - trespass & malicious trespass')
#
# <ipython-input-14-bbec6d487581> in __init__(self, content)
#      11     def __init__(self, content):
#      12         self.info = {}
# ---> 13         self.parse(content)
#      14
#      15     def parse(self, content):
#
# <ipython-input-14-bbec6d487581> in parse(self, content)
#      25             if re.match(Record.TIME_PATTERN, line):
#      26                 line = next(line_itr)
# ---> 27                 t_from, t_to = self.parse_from_to_time(line)
#      28                 self.info['from datetime'] = t_from
#      29                 self.info['to datetime'] = t_to
#
# <ipython-input-14-bbec6d487581> in parse_from_to_time(self, timestr)
#      30
#      31     def parse_from_to_time(self, timestr):
# ---> 32         fromdate, fromtime, todate, totime = timestr.split('-')
#      33         fromtime = fromtime.split('at')[1].strip()
#      34         totime = totime.split('at')[1].strip()
#
# ValueError: not enough values to unpack (expected 4, got 3)
