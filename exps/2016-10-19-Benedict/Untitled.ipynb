# %%
# %load_ext autoreload
# %autoreload 2
import os
import glob
import random
import re
from datetime import *

#from iucrime.records import Record

# %%
path = '../../data/scrapped/text/2016'
files = glob.glob(os.path.join(path, '*'))
fname = random.choice(files)

print(open(fname).read())
# Out:
# Indiana University, Bloomington
#
# Police Department
# Daily crime log report
# from 07/08/2016 00:00 to 07/08/2016 23:59
# date reported: 07/08/16 - FRI at 02:17
# location:
#
# cad event #:
#
# 16-07-08-013909
#
# TETER QUAD, 501 N. SUNRISE, BOSEN 2ND FLOOR
#
# incident: POSSESSION - MARIJUANA
# final incident: POSSESSION - MARIJUANA
# disposition: FAILED TO LOCATE
# modified date: 07/08/16 - FRI at 02:34
# date reported: 07/08/16 - FRI at 03:33
# general location:
#
# report #:
#
# 161558
#
# ALL OTHER NON-UNIVERSITY – 7th and Walnut
#
# date occurred from: 07/08/16 - FRI at 03:33
# date occurred to:
#
# 07/08/16 - FRI at 03:45
#
# incident/offenses:
#
# DRUNKENNESS - PUBLIC INTOXICATION
#
# disposition: CLOSED CASE- ARREST
# modified date: 07/08/16 - FRI at 05:36
# date reported: 07/08/16 - FRI at 08:34
# general location:
#
# report #:
#
# 161560
#
# 12TH STREET/WEST OF JORDAN - Public property
#
# date occurred from: 07/08/16 - FRI at 08:33
# date occurred to:
#
# 07/08/16 - FRI at 08:34
#
# incident/offenses:
#
# DRUNK DRIVING - DRIVING UNDER THE INFLUENCE
#
# disposition: CLOSED CASE- ARREST
# modified date: 07/11/16 - MON at 09:05
# date reported: 07/08/16 - FRI at 11:23
# general location:
#
# report #:
#
# 161561
#
# WELLS LIBRARY - On Campus
#
# date occurred from: 07/07/16 - THU at 13:00
# date occurred to:
#
# 07/08/16 - FRI at 11:00
#
# incident/offenses:
#
# LARCENY-THEFT - THEFT FROM BUILDINGS
#
# disposition: OPEN CASE
# modified date: 07/11/16 - MON at 11:16
# date reported: 07/08/16 - FRI at 14:21
# general location:
#
# report #:
#
# 161562
#
# EIGENMANN HALL COMMON AREA - On Campus
#
# date occurred from: 07/06/16 - WED at 14:00
# date occurred to:
#
# 07/06/16 - WED at 18:30
#
# incident/offenses:
#
# LARCENY-THEFT - THEFT FROM BUILDINGS
#
# disposition: OPEN CASE
# modified date: 07/11/16 - MON at 11:21

# %%
import re
from pprint import pprint
import datetime

class Record():
    """ class for keeping the daily IU police log """

    INFO_PATTERN = re.compile('^(location|incident|disposition|event #|report #)\s*:\s*(.+)', re.IGNORECASE)
    TIME_PATTERN = re.compile('^date and time occurred.*from.*to', re.IGNORECASE)
    LOCATION_PATTERN = re.compile('^(general location)\s*:\s*.*', re.DOTALL)
    
    def __init__(self, content):
        self.info = {}
        
        self.parse(content)
    
    def parse(self, content):
        line_itr = iter(content.splitlines())
        
#         new_group = 
        for line in line_itr:
            
            m = re.search(Record.LOCATION_PATTERN, line)
            if m:
                key = m.group(1).lower().replace('#', 'number')
                val = m.group(2).lower()
                self.info[key] = val
#                

                continue
                
            if re.match(Record.TIME_PATTERN, line):
                line = next(line_itr)
                t_from, t_to = self.parse_from_to_time(line)
                self.info['from datetime'] = t_from
                self.info['to datetime'] = t_to
                
    def parse_from_to_time(self, timestr):
        fromdate, fromtime, todate, totime = timestr.split('-')
        fromtime = fromtime.split('at')[1].strip()
        totime = totime.split('at')[1].strip()
        t_from = datetime.datetime.strptime(' '.join([fromdate.strip(), fromtime]), '%m/%d/%y %H:%M')
        t_to = datetime.datetime.strptime(' '.join([todate.strip(), totime]), '%m/%d/%y %H:%M')
        return (t_from, t_to)
                
r = Record(open(fname).read())
# assert(r.info['location'] == 'indiana memorial union')
# assert(r.info['incident'] == 'all other offenses - trespass & malicious trespass')
pprint(r.info)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-0a28b90c251d> in <module>()
#      44         return (t_from, t_to)
#      45
# ---> 46 r = Record(open(fname).read())
#      47 # assert(r.info['location'] == 'indiana memorial union')
#      48 # assert(r.info['incident'] == 'all other offenses - trespass & malicious trespass')
#
# <ipython-input-66-0a28b90c251d> in __init__(self, content)
#      13         self.info = {}
#      14
# ---> 15         self.parse(content)
#      16
#      17     def parse(self, content):
#
# <ipython-input-66-0a28b90c251d> in parse(self, content)
#      24             if m:
#      25                 key = m.group(1).lower().replace('#', 'number')
# ---> 26                 val = m.group(2).lower()
#      27                 self.info[key] = val
#      28 #
#
# IndexError: no such group

# %%
import re
from pprint import pprint
import datetime

class Record():
    """ class for keeping the daily IU police log """

    INFO_PATTERN = re.compile('^(location|incident|disposition|event #|report #)\s*:\s*(.+)', re.IGNORECASE)
    TIME_PATTERN = re.compile('^date and time occurred.*from.*to', re.IGNORECASE)
    
    def __init__(self, content):
        self.info = {}
        
        self.parse(content)
    
    def parse(self, content):
        line_itr = iter(content.splitlines())
        
#         new_group = 
        for line in line_itr:
            
            m = re.search(Record.INFO_PATTERN, line)
            if m:
                key = m.group(1).lower().replace('#', 'number')
                val = m.group(2).lower()
                if key in self.info:
                    self.info[key] += val + ','
#                     print('dogs')
                else:
                    self.info[key] = val +','
#                 print(key)
#                 print(self.info[key])

                continue
                
            if re.match(Record.TIME_PATTERN, line):
                line = next(line_itr)
                t_from, t_to = self.parse_from_to_time(line)
                self.info['from datetime'] = t_from
                self.info['to datetime'] = t_to
                
    def parse_from_to_time(self, timestr):
        fromdate, fromtime, todate, totime = timestr.split('-')
        fromtime = fromtime.split('at')[1].strip()
        totime = totime.split('at')[1].strip()
        t_from = datetime.datetime.strptime(' '.join([fromdate.strip(), fromtime]), '%m/%d/%y %H:%M')
        t_to = datetime.datetime.strptime(' '.join([todate.strip(), totime]), '%m/%d/%y %H:%M')
        return (t_from, t_to)
                
r = Record(open(fname).read())
# assert(r.info['location'] == 'indiana memorial union')
# assert(r.info['incident'] == 'all other offenses - trespass & malicious trespass')
pprint(r.info)
# Out:
# {'disposition': 'closed by arrest,active,inactive,',
#  'event number': '13-01-02-000048,13-01-02-000098,13-01-02-000103,',
#  'from datetime': datetime.datetime(2012, 10, 26, 1, 30),
#  'incident': 'drunk driving - driving under the influence,larceny-theft - from '
#              'buildings,sex off/non-forcible - all other-non forcible,',
#  'location': 'all other non-university,teter quad,1200 block n jordan ave,',
#  'report number': '130003,130005,130006,',
#  'to datetime': datetime.datetime(2012, 10, 26, 3, 30)}

# %%
import re
from pprint import pprint
import datetime

class Record():
    """ class for keeping the daily IU police log """

    INFO_PATTERN = re.compile('^(location|incident|disposition|event #|report #)\s*:\s*(.+)', re.IGNORECASE)
    TIME_PATTERN = re.compile('^date and time occurred.*from.*to', re.IGNORECASE)
    
    def __init__(self, content):
        self.info = {}
        
        self.parse(content)
    
    def parse(self, content):
        line_itr = iter(content.splitlines())
        
        new_group = 
        for line in line_itr:
            
            m = re.search(Record.INFO_PATTERN, line)
            if m:
                key = m.group(1).lower().replace('#', 'number')
                val = m.group(2).lower()
                self.info[key] = val
                continue
                
            if re.match(Record.TIME_PATTERN, line):
                line = next(line_itr)
                t_from, t_to = self.parse_from_to_time(line)
                self.info['from datetime'] = t_from
                self.info['to datetime'] = t_to
                
    def parse_from_to_time(self, timestr):
        fromdate, fromtime, todate, totime = timestr.split('-')
        fromtime = fromtime.split('at')[1].strip()
        totime = totime.split('at')[1].strip()
        t_from = datetime.datetime.strptime(' '.join([fromdate.strip(), fromtime]), '%m/%d/%y %H:%M')
        t_to = datetime.datetime.strptime(' '.join([todate.strip(), totime]), '%m/%d/%y %H:%M')
        return (t_from, t_to)
                
r = Record(open(fname).read())
# assert(r.info['location'] == 'indiana memorial union')
# assert(r.info['incident'] == 'all other offenses - trespass & malicious trespass')
pprint(r.info)
